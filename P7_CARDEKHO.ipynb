# %% [markdown]
# ## **Importing necessary libraries**

# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## **Insight of Data**

# %%
df = pd.read_csv("/content/cardekho_imputated.csv")
df.head(10)
# Out:
#    Unnamed: 0        car_name    brand     model  vehicle_age  km_driven  \
# 0           0     Maruti Alto   Maruti      Alto            9     120000
# 1           1   Hyundai Grand  Hyundai     Grand            5      20000
# 2           2     Hyundai i20  Hyundai       i20           11      60000
# 3           3     Maruti Alto   Maruti      Alto            9      37000
# 4           4   Ford Ecosport     Ford  Ecosport            6      30000
# 5           5  Maruti Wagon R   Maruti   Wagon R            8      35000
# 6           6     Hyundai i10  Hyundai       i10            8      40000
# 7           7  Maruti Wagon R   Maruti   Wagon R            3      17512
# 8           8   Hyundai Venue  Hyundai     Venue            2      20000
# 9          12    Maruti Swift   Maruti     Swift            4      28321
#
#   seller_type fuel_type transmission_type  mileage  engine  max_power  seats  \
# 0  Individual    Petrol            Manual    19.70     796      46.30      5
# ...

# %%
df.shape
# Out:
# (15411, 14)

# %%
df.dtypes
# Out:
# Unnamed: 0             int64
# car_name              object
# brand                 object
# model                 object
# vehicle_age            int64
# km_driven              int64
# seller_type           object
# fuel_type             object
# transmission_type     object
# mileage              float64
# engine                 int64
# max_power            float64
# seats                  int64
# selling_price          int64
# dtype: object

# %% [markdown]
# # **Separating** different datatypes column's

# %%
obj = df.select_dtypes(include='object')
init = df.select_dtypes(include='int')
flo = df.select_dtypes(include='float')

print("obj.columns:\n",obj.columns)
print("init.columns:\n",init.columns)
print("flo.columns:\n",flo.columns)
# Out:
# obj.columns:
#  Index(['car_name', 'brand', 'model', 'seller_type', 'fuel_type',
#        'transmission_type'],
#       dtype='object')
# init.columns:
#  Index(['Unnamed: 0', 'vehicle_age', 'km_driven', 'engine', 'seats',
#        'selling_price'],
#       dtype='object')
# flo.columns:
#  Index(['mileage', 'max_power'], dtype='object')

# %%
df.isnull().sum()
# Out:
# Unnamed: 0           0
# car_name             0
# brand                0
# model                0
# vehicle_age          0
# km_driven            0
# seller_type          0
# fuel_type            0
# transmission_type    0
# mileage              0
# engine               0
# max_power            0
# seats                0
# selling_price        0
# dtype: int64

# %%
df.describe()
# Out:
#          Unnamed: 0   vehicle_age     km_driven       mileage        engine  \
# count  15411.000000  15411.000000  1.541100e+04  15411.000000  15411.000000
# mean    9811.857699      6.036338  5.561648e+04     19.701151   1486.057751
# std     5643.418542      3.013291  5.161855e+04      4.171265    521.106696
# min        0.000000      0.000000  1.000000e+02      4.000000    793.000000
# 25%     4906.500000      4.000000  3.000000e+04     17.000000   1197.000000
# 50%     9872.000000      6.000000  5.000000e+04     19.670000   1248.000000
# 75%    14668.500000      8.000000  7.000000e+04     22.700000   1582.000000
# max    19543.000000     29.000000  3.800000e+06     33.540000   6592.000000
#
#           max_power         seats  selling_price
# count  15411.000000  15411.000000   1.541100e+04
# mean     100.588254      5.325482   7.749711e+05
# std       42.972979      0.807628   8.941284e+05
# min       38.400000      0.000000   4.000000e+04
# ...

# %%
df.isna().sum()
# Out:
# Unnamed: 0           0
# car_name             0
# brand                0
# model                0
# vehicle_age          0
# km_driven            0
# seller_type          0
# fuel_type            0
# transmission_type    0
# mileage              0
# engine               0
# max_power            0
# seats                0
# selling_price        0
# dtype: int64

# %%
df.drop('Unnamed: 0',axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15411 entries, 0 to 15410
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   car_name           15411 non-null  object
#  1   brand              15411 non-null  object
#  2   model              15411 non-null  object
#  3   vehicle_age        15411 non-null  int64
#  4   km_driven          15411 non-null  int64
#  5   seller_type        15411 non-null  object
#  6   fuel_type          15411 non-null  object
#  7   transmission_type  15411 non-null  object
#  8   mileage            15411 non-null  float64
#  9   engine             15411 non-null  int64
#  10  max_power          15411 non-null  float64
#  11  seats              15411 non-null  int64
#  12  selling_price      15411 non-null  int64
# dtypes: float64(2), int64(5), object(6)
# memory usage: 1.5+ MB

# %%
df
# Out:
#               car_name     brand     model  vehicle_age  km_driven  \
# 0          Maruti Alto    Maruti      Alto            9     120000
# 1        Hyundai Grand   Hyundai     Grand            5      20000
# 2          Hyundai i20   Hyundai       i20           11      60000
# 3          Maruti Alto    Maruti      Alto            9      37000
# 4        Ford Ecosport      Ford  Ecosport            6      30000
# ...                ...       ...       ...          ...        ...
# 15406      Hyundai i10   Hyundai       i10            9      10723
# 15407    Maruti Ertiga    Maruti    Ertiga            2      18000
# 15408      Skoda Rapid     Skoda     Rapid            6      67000
# 15409  Mahindra XUV500  Mahindra    XUV500            5    3800000
# 15410       Honda City     Honda      City            2      13000
#
#       seller_type fuel_type transmission_type  mileage  engine  max_power  \
# 0      Individual    Petrol            Manual    19.70     796      46.30
# ...

# %%
df['car_name'].nunique()
# Out:
# 121

# %%
best_selling =df['car_name'].value_counts().head(10) ## best selling top 5 car model....
best_selling
# Out:
# car_name
# Hyundai i20           906
# Maruti Swift Dzire    890
# Maruti Swift          781
# Maruti Alto           778
# Honda City            757
# Maruti Wagon R        717
# Hyundai Grand         580
# Toyota Innova         545
# Hyundai Verna         492
# Hyundai i10           410
# Name: count, dtype: int64

# %% [markdown]
# ## **Separating index and values to plot the chart of top selling models **

# %%
x= df['car_name'].value_counts().head(10).index
print(x)
# Out:
# Index(['Hyundai i20', 'Maruti Swift Dzire', 'Maruti Swift', 'Maruti Alto',
#        'Honda City', 'Maruti Wagon R', 'Hyundai Grand', 'Toyota Innova',
#        'Hyundai Verna', 'Hyundai i10'],
#       dtype='object', name='car_name')

# %%
y = df['car_name'].value_counts().head(10).values
print(y)
# Out:
# [906 890 781 778 757 717 580 545 492 410]

# %%
plt.figure(figsize=(10,5))
bars = plt.bar(x,y,color = "black")
for bar in bars:
  plt.text(bar.get_x()+bar.get_width()/2,
          bar.get_height(),f"{bar.get_height():.1f}",
          ha = "center",va="bottom",fontsize=12)

plt.bar(x,y)
plt.xlabel("car_names")
plt.xticks(rotation=90)
plt.ylabel("car_names_values")
plt.title("best selling top 5 car model")
plt.show()

# %%
df['transmission_type'].nunique()
# Out:
# 2

# %%
manual = []
auto =[]
for car_name in best_selling.index:
  transmission = df[df['car_name'] == car_name]['transmission_type'].iloc[0]   ## here iloc[0] means index zero having names of that cars
  if transmission == "Manual":
    manual.append(car_name)
  else:
    auto.append(car_name)

print("Manual transmission best-selling cars:\n", manual)
print("Automatic transmission best-selling cars:", auto)
# Out:
# Manual transmission best-selling cars:
#  ['Hyundai i20', 'Maruti Swift Dzire', 'Maruti Swift', 'Maruti Alto', 'Honda City', 'Maruti Wagon R', 'Hyundai Grand', 'Toyota Innova', 'Hyundai Verna', 'Hyundai i10']
# Automatic transmission best-selling cars: []

# %%
df.head(3)
# Out:
#         car_name    brand  model  vehicle_age  km_driven seller_type  \
# 0    Maruti Alto   Maruti   Alto            9     120000  Individual
# 1  Hyundai Grand  Hyundai  Grand            5      20000  Individual
# 2    Hyundai i20  Hyundai    i20           11      60000  Individual
#
#   fuel_type transmission_type  mileage  engine  max_power  seats  \
# 0    Petrol            Manual     19.7     796       46.3      5
# 1    Petrol            Manual     18.9    1197       82.0      5
# 2    Petrol            Manual     17.0    1197       80.0      5
#
#    selling_price
# 0         120000
# 1         550000
# 2         215000

# %%
df['seller_type'].unique()
# Out:
# array(['Individual', 'Dealer', 'Trustmark Dealer'], dtype=object)

# %% [markdown]
# ## THERE ARE TWO WAYS TO PLOT THE CHARTS
#
# 1). IN FIRST WE ARE PLOTTING THE ONLY DESIRED COLUMNS IN HORIZOINTAL MANNER.
#
# 2). BUT IN SECOUND WE ARE PLOTTING THE ALL COLUMNS ,. BUT HERE LIMITS OF UNIQUE EXCEEDS FROM THE PLOT RANGE SO WE USE THE IF CONDITION TO PLOT THE REQUIRED NO. OF DATA

# %%
figure, axis = plt.subplots(1, 3, figsize=(15, 5)) # Adjusted figsize for better readability
sns.countplot(x='seller_type',data=df,ax=axis[0])
sns.countplot(x='fuel_type',data=df,ax=axis[1])
sns.countplot(x='transmission_type',data=df,ax=axis[2])
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

for col in df.columns:
  # Check if the column is suitable for a count plot (e.g., not too many unique values)
  if df[col].nunique() < 50: # You can adjust this threshold
    plt.figure(figsize=(10, 6)) # Create a new figure for each plot
    sns.countplot(x=col, data=df)
    plt.title(f'Distribution of {col}')
    plt.xticks(rotation=45, ha='right') # Rotate labels for better readability
    plt.tight_layout() # Adjust layout to prevent labels overlapping
    plt.show()
  else:
    print(f"Skipping plot for column '{col}' due to too many unique values.")
# Out:
# Skipping plot for column 'car_name' due to too many unique values.
# Skipping plot for column 'model' due to too many unique values.
# Skipping plot for column 'km_driven' due to too many unique values.
# Skipping plot for column 'mileage' due to too many unique values.
# Skipping plot for column 'engine' due to too many unique values.
# Skipping plot for column 'max_power' due to too many unique values.
# Skipping plot for column 'selling_price' due to too many unique values.

# %%
df.head(3)
# Out:
#         car_name    brand  model  vehicle_age  km_driven seller_type  \
# 0    Maruti Alto   Maruti   Alto            9     120000  Individual
# 1  Hyundai Grand  Hyundai  Grand            5      20000  Individual
# 2    Hyundai i20  Hyundai    i20           11      60000  Individual
#
#   fuel_type transmission_type  mileage  engine  max_power  seats  \
# 0    Petrol            Manual     19.7     796       46.3      5
# 1    Petrol            Manual     18.9    1197       82.0      5
# 2    Petrol            Manual     17.0    1197       80.0      5
#
#    selling_price
# 0         120000
# 1         550000
# 2         215000

# %%
df.plot.scatter('selling_price','km_driven',title="Selling Price Vs Km driven",color="MEDIUMVIOLETRED")
# Out:
# <Axes: title={'center': 'Selling Price Vs Km driven'}, xlabel='selling_price', ylabel='km_driven'>

# %%
num_col = df.select_dtypes(include='number')
plt.figure(figsize=(10,5))
sns.heatmap(num_col.corr(),annot=True,cmap = "BrBG",linewidths=2,fmt='0.2f')
plt.show()

# %%
df
# Out:
#               car_name     brand     model  vehicle_age  km_driven  \
# 0          Maruti Alto    Maruti      Alto            9     120000
# 1        Hyundai Grand   Hyundai     Grand            5      20000
# 2          Hyundai i20   Hyundai       i20           11      60000
# 3          Maruti Alto    Maruti      Alto            9      37000
# 4        Ford Ecosport      Ford  Ecosport            6      30000
# ...                ...       ...       ...          ...        ...
# 15406      Hyundai i10   Hyundai       i10            9      10723
# 15407    Maruti Ertiga    Maruti    Ertiga            2      18000
# 15408      Skoda Rapid     Skoda     Rapid            6      67000
# 15409  Mahindra XUV500  Mahindra    XUV500            5    3800000
# 15410       Honda City     Honda      City            2      13000
#
#       seller_type fuel_type transmission_type  mileage  engine  max_power  \
# 0      Individual    Petrol            Manual    19.70     796      46.30
# ...

# %% [markdown]
# ## **FOR MACHINE LEARNING MODEL**

# %%
df
# Out:
#               car_name     brand     model  vehicle_age  km_driven  \
# 0          Maruti Alto    Maruti      Alto            9     120000
# 1        Hyundai Grand   Hyundai     Grand            5      20000
# 2          Hyundai i20   Hyundai       i20           11      60000
# 3          Maruti Alto    Maruti      Alto            9      37000
# 4        Ford Ecosport      Ford  Ecosport            6      30000
# ...                ...       ...       ...          ...        ...
# 15406      Hyundai i10   Hyundai       i10            9      10723
# 15407    Maruti Ertiga    Maruti    Ertiga            2      18000
# 15408      Skoda Rapid     Skoda     Rapid            6      67000
# 15409  Mahindra XUV500  Mahindra    XUV500            5    3800000
# 15410       Honda City     Honda      City            2      13000
#
#       seller_type fuel_type transmission_type  mileage  engine  max_power  \
# 0      Individual    Petrol            Manual    19.70     796      46.30
# ...

# %%
obj = df.select_dtypes(include='object')
init = df.select_dtypes(include='int')
flo = df.select_dtypes(include='float')

print("obj.columns:\n",obj.columns)
print("init.columns:\n",init.columns)
print("flo.columns:\n",flo.columns)
# Out:
# obj.columns:
#  Index(['car_name', 'brand', 'model', 'seller_type', 'fuel_type',
#        'transmission_type'],
#       dtype='object')
# init.columns:
#  Index(['vehicle_age', 'km_driven', 'engine', 'seats', 'selling_price'], dtype='object')
# flo.columns:
#  Index(['mileage', 'max_power'], dtype='object')

# %% [markdown]
# ## **Encoding Categorical Variables**

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder

le = LabelEncoder()
df['seller_type'] = le.fit_transform(df['seller_type'])
df['fuel_type'] = le.fit_transform(df['fuel_type'])
df['transmission_type'] = le.fit_transform(df['transmission_type'])

print(df['seller_type'].nunique())
print(df['fuel_type'].nunique())
print(df['transmission_type'].nunique())
# Out:
# 3
# 5
# 2

# %%
df['seller_type'].unique()
# Out:
# array([1, 0, 2])

# %%
ohe_df = pd.get_dummies(df['seller_type'])

# %%
df = df.drop(['car_name','model'], axis=1)

# %%
df
# Out:
#           brand  vehicle_age  km_driven  seller_type  fuel_type  \
# 0        Maruti            9     120000            1          4
# 1       Hyundai            5      20000            1          4
# 2       Hyundai           11      60000            1          4
# 3        Maruti            9      37000            1          4
# 4          Ford            6      30000            0          1
# ...         ...          ...        ...          ...        ...
# 15406   Hyundai            9      10723            0          4
# 15407    Maruti            2      18000            0          4
# 15408     Skoda            6      67000            0          1
# 15409  Mahindra            5    3800000            0          1
# 15410     Honda            2      13000            0          4
#
#        transmission_type  mileage  engine  max_power  seats  selling_price
# 0                      1    19.70     796      46.30      5         120000
# ...

# %%
df['seats'].unique()
# Out:
# array([5, 8, 7, 6, 4, 2, 9, 0])

# %%
df['brand'].nunique()
# Out:
# 32

# %%
# !pip install category_encoders
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.7/85.7 kB 7.0 MB/s eta 0:00:00
# ...

# %%
import category_encoders as ce

# %% [markdown]
# Now, I will modify the cell to use the `TargetEncoder`.

# %%
# Modify the code in cell 9fMCpjDSvktL
# The original code had a NameError because TargetEncoder was not imported.
# It also had an issue in the transform method, where it was trying to transform the entire DataFrame instead of the specific column.

te = ce.TargetEncoder()
te.fit(X=df['brand'], y=df['selling_price'])
values = te.transform(df['brand'])
df.drop(['brand'], axis=1, inplace=True)
df = pd.concat([df, values], axis=1)

# Rename the new column if necessary (e.g., to 'brand_encoded')
# df = df.rename(columns={'brand': 'brand_encoded'}) # Uncomment and adjust if you want to rename the column

display(df.head())
# Out:
#    vehicle_age  km_driven  seller_type  fuel_type  transmission_type  mileage  \
# 0            9     120000            1          4                  1    19.70
# 1            5      20000            1          4                  1    18.90
# 2           11      60000            1          4                  1    17.00
# 3            9      37000            1          4                  1    20.92
# 4            6      30000            0          1                  1    22.77
#
#    engine  max_power  seats  selling_price          brand
# 0     796      46.30      5         120000  487089.317909
# 1    1197      82.00      5         550000  576153.923541
# 2    1197      80.00      5         215000  576153.923541
# 3     998      67.10      5         226000  487089.317909
# 4    1498      98.59      5         570000  645224.050633

# %% [markdown]
# ## **Calling And training models**

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR

x = df.drop('selling_price',axis=1)
y = df['selling_price']

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

rf = RandomForestRegressor(n_estimators=100, max_depth=6, random_state=42)
rf.fit(x_train,y_train)
y_pred = rf.predict(x_test)

mse = mean_squared_error(y_test,y_pred)
r2 = r2_score(y_test,y_pred)

print(mse)
print(r2)
# Out:
# 70860686395.11877
# 0.9058682246423184

# %%
importance = rf.feature_importances_
feature_names = x.columns
indices = np.argsort(importance)[::-1]

# Plot
plt.figure(figsize=(10, 6))
plt.title("Feature Importance - Random Forest Regressor")
plt.bar(range(x.shape[1]), importance[indices], align="center")
plt.xticks(range(x.shape[1]), feature_names[indices], rotation=45)
plt.ylabel("Importance Score")
plt.tight_layout()
plt.show()

# %%
# Train Decision Tree Regressor
tree = DecisionTreeRegressor(max_depth=6, random_state=42)
tree.fit(x_train, y_train)
tree_pred = tree.predict(x_test)
tree_mse = mean_squared_error(y_test, tree_pred)
tree_r2 = r2_score(y_test, tree_pred)

# Train Linear Regression
lr = LinearRegression()
lr.fit(x_train, y_train)
lr_pred = lr.predict(x_test)
lr_mse = mean_squared_error(y_test, lr_pred)
lr_r2 = r2_score(y_test, lr_pred)

# Random Forest (already trained)
rf_pred = rf.predict(x_test)
rf_mse = mean_squared_error(y_test, rf_pred)
rf_r2 = r2_score(y_test, rf_pred)

# Create comparison table
comparison_df = pd.DataFrame({
    "Model": ["Linear Regression", "Decision Tree", "Random Forest"],
    "MSE": [lr_mse, tree_mse, rf_mse],
    "R² Score": [lr_r2, tree_r2, rf_r2]
})

comparison_df
# Out:
#                Model           MSE  R² Score
# 0  Linear Regression  2.236010e+11  0.702967
# 1      Decision Tree  1.012543e+11  0.865493
# 2      Random Forest  7.086069e+10  0.905868

# %%
from sklearn.tree import DecisionTreeClassifier, plot_tree
import matplotlib.pyplot as plt

# Train two trees: one with Gini and one with Entropy
clf_gini = DecisionTreeClassifier(criterion='gini', max_depth=3, random_state=42)
#clf_entropy = DecisionTreeClassifier(criterion='entropy', max_depth=3, random_state=42)

clf_gini.fit(x, y)
#clf_entropy.fit(x, y)

# Plot both trees side by side
fig, axes = plt.subplots(1,2,figsize=(16, 6))

plot_tree(clf_gini, filled=True, feature_names=x.columns, class_names=[str(c) for c in y.unique()], ax=axes[0])
axes[0].set_title("Decision Tree (Gini Impurity)")

# Since we are doing regression, class_names is not directly applicable in the same way as classification.
# If you want to visualize a regression tree, you might consider other visualization methods or adapt this one.
# For now, I will comment out the entropy tree plotting as the error also mentions target_names which is for classification.
# plot_tree(clf_entropy, filled=True, feature_names=x.columns, class_names=[str(c) for c in y.unique()], ax=axes[1])
# axes[1].set_title("Decision Tree (Entropy)")

plt.tight_layout()
plt.show()

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

lr = LinearRegression()
lr.fit(x_train,y_train)
y_pred = lr.predict(x_test)

mse = mean_squared_error(y_test,y_pred)
r2 = r2_score(y_test,y_pred)
# acc = accuracy_score(y_test,y_pred) # This metric is for classification, not regression

print(round(mse/1000000))
print(r2)
# print(acc) # This metric is for classification, not regression
# Out:
# 223601
# 0.7029670700892781

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.metrics import accuracy_score, mean_squared_error, r2_score

# Initialize models

models = {"Decision_Tree":DecisionTreeClassifier(random_state=42),
          "RandomForest":RandomForestClassifier(n_estimators=100,random_state=42),
          "Adaboost":AdaBoostClassifier(
              estimator=DecisionTreeClassifier(max_depth=1),
              n_estimators=50,
              random_state=42
          )}

result =[]
for name,model in models.items():
  model.fit(x_train,y_train)
  y_pred = model.predict(x_test)

  r2 = r2_score(y_test,y_pred)
  acc = accuracy_score(y_test,y_pred)
  result.append([name,acc])

# Create DataFrame of results
results_df = pd.DataFrame(result, columns=["Model", "Accuracy"])
print(results_df)
# Out:
#            Model  Accuracy
# 0  Decision_Tree  0.050600
# 1   RandomForest  0.052546
# 2       Adaboost  0.028219
